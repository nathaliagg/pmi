# %% [markdown]
# I need to manually check each metadata because they entered controls in different ways...
#
# Studies 10321 and 13450 don't seem to have a control.

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.5'

# %%
id714 = pd.read_csv('714/templates/714_20191015-105331.txt', sep = '\t')
id714 = id714[id714['treatment']=='control'].reset_index(drop=True)
id714.to_csv('714/templates/control_714.txt', sep='\t', index=False)
id714[['sample_name']].to_csv('714/templates/samples_to_keep_714.tsv', sep='\t', index=False)
id714.head()
# Out:
#             sample_name  age age_unit  altitude   anonymized_name  \
# 0          714.M3ntc.D6  NaN     days         0          M3ntc.D6
# 1         714.M3ntc.H12  NaN     days         0         M3ntc.H12
# 2        714.clean.swab  NaN     days         0        clean.swab
# 3           714.control  NaN     days         0           control
# 4  714.control.MCD1.H12  NaN     days         0  control.MCD1.H12
#
#      biological_specimen body_habitat body_product body_site     cage  ...  \
# 0  mouse.control.control          NaN          NaN       NaN  control  ...
# 1  mouse.control.control          NaN          NaN       NaN  control  ...
# 2  mouse.control.control          NaN          NaN       NaN  control  ...
# 3  mouse.control.control          NaN          NaN       NaN  control  ...
# 4  mouse.control.control          NaN          NaN       NaN  control  ...
#
#   soil_controls  soil_ph  time_bin                        title treatment  \
# ...

# %%
id1609 = pd.read_csv('1609/templates/1609_20181018-131039.txt', sep='\t')
id1609 = id1609[id1609['control']=='y'].reset_index(drop=True)
id1609.to_csv('1609/templates/control_1609.txt', sep='\t', index=False)
id1609[['sample_name']].to_csv('1609/templates/samples_to_keep_1609.tsv', sep='\t', index=False)
id1609.head()
# Out:
#              sample_name      ammonium ammonium_units anonymized_name  \
# 0  1609.mass.control.0.1  Not provided   Not provided              A1
# 1  1609.mass.control.0.2  Not provided   Not provided              A2
# 2  1609.mass.control.0.3  Not provided   Not provided              A3
# 3  1609.mass.control.1.1  Not provided   Not provided              A4
# 4  1609.mass.control.1.2  Not provided   Not provided              A5
#
#    collection_timestamp control country  depth       description  \
# 0                  2014       y  USA:NE  0-.05  mass.control.0.1
# 1                  2014       y  USA:NE  0-.05  mass.control.0.2
# 2                  2014       y  USA:NE  0-.05  mass.control.0.3
# 3                  2014       y  USA:NE  0-.05  mass.control.1.1
# 4                  2014       y  USA:NE  0-.05  mass.control.1.2
#
#    dna_extracted  ...  sample_type  scientific_name          season taxon_id  \
# ...

# %%
id10141 = pd.read_csv('10141/templates/10141_20190104-105500.txt', sep='\t')
id10141 = id10141[id10141['sample_type']=='control'].reset_index(drop=True)
id10141.to_csv('10141/templates/control_10141.txt', sep='\t', index=False)
id10141[['sample_name']].to_csv('10141/templates/samples_to_keep_10141.tsv', sep='\t', index=False)
id10141.head()
# Out:
#          sample_name anonymized_name collection_date collection_timestamp  \
# 0  10141.NTC.plate.8     NTC.plate.8   12/17/12 0:00           2012-12-17
# 1   10141.NTC.plate1      NTC.plate1   12/17/12 0:00           2012-12-17
# 2   10141.NTC.plate2      NTC.plate2   12/17/12 0:00           2012-12-17
# 3   10141.NTC.plate3      NTC.plate3   12/17/12 0:00           2012-12-17
# 4   10141.NTC.plate4      NTC.plate4   12/17/12 0:00           2012-12-17
#
#                         country  depth  \
# 0  GAZ:United States of America      0
# 1  GAZ:United States of America      0
# 2  GAZ:United States of America      0
# 3  GAZ:United States of America      0
# 4  GAZ:United States of America      0
#
#                                          description  dna_extracted  \
# 0  Mouse Decomposition experiment on contrasting ...           True
# 1  Mouse Decomposition experiment on contrasting ...           True
# 2  Mouse Decomposition experiment on contrasting ...           True
# ...

# %%
id10143 = pd.read_csv('10143/templates/10143_20191021-130723.txt', sep='\t')
id10143 = id10143[id10143['sample_name'].str.contains('ctrl')].reset_index(drop=True)
id10143.to_csv('10143/templates/control_10143.txt', sep='\t', index=False)
id10143[['sample_name']].to_csv('10143/templates/samples_to_keep_10143.tsv', sep='\t', index=False)
id10143.head()
# Out:
#                            sample_name     add_0c     add_4c     add_5c  \
# 0  10143.016.4.17.2013.Soil.ctrl.ctrlA   0.000000   0.000000   0.000000
# 1  10143.016.4.17.2013.Soil.ctrl.ctrlB   0.000000   0.000000   0.000000
# 2  10143.016.4.17.2013.Soil.ctrl.ctrlC   0.000000   0.000000   0.000000
# 3  10143.016.4.19.2013.Soil.ctrl.ctrlA  26.576191  18.576191  16.576191
# 4  10143.016.4.19.2013.Soil.ctrl.ctrlB  26.576191  18.576191  16.576191
#
#      add_6c body_site collection_date collection_date_unformat  \
# 0   0.00000      ctrl       4.17.2013                4.17.2013
# 1   0.00000      ctrl       4.17.2013                4.17.2013
# 2   0.00000      ctrl       4.17.2013                4.17.2013
# 3  10.28766      ctrl       4.19.2013                4.19.2013
# 4  10.28766      ctrl       4.19.2013                4.19.2013
#
#   collection_timestamp corrected_sample_site  ...    soil_type  \
# 0           2013-04-17                  ctrl  ...  pine_forest
# ...

# %%
## All samples comes from fly, and doesn't seem to have a control

# id10321 = pd.read_csv('10321/templates/10321_20180418-105405.txt', sep='\t')
# id10321
